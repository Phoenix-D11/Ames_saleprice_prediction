# %%
import numpy as np
from numpy import nan
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime, date, time
from sklearn.preprocessing import LabelEncoder, OneHotEncoder 

import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

sns.set_style("darkgrid")

# %%
df = pd.read_csv("./CSV files/train.csv")
df_test = pd.read_csv("./CSV files/ames_test.csv")
df.sample(10)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 849    850          80       RL         80.0     9600   Pave   NaN      Reg
# 1405  1406         120       RM         44.0     3842   Pave   NaN      IR1
# 297    298          60       FV         66.0     7399   Pave  Pave      IR1
# 1306  1307         120       RL         48.0     6955   Pave   NaN      IR1
# 531    532          70       RM         60.0     6155   Pave   NaN      IR1
# 330    331          90       RL          NaN    10624   Pave   NaN      IR1
# 681    682          50       RH         55.0     4500   Pave  Pave      IR2
# 333    334         120       RM         59.0     8198   Pave   NaN      Reg
# 888    889          20       RL         95.0    15865   Pave   NaN      IR1
# 1022  1023          50       RM         52.0     9439   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 849          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1405         HLS    AllPub  ...        0    NaN   NaN         NaN       0
# 297          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1306         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 531          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 330          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 681          Bnk    AllPub  ...        0    NaN   NaN         NaN       0
# 333          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 888          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1022         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 849       8   2007        WD         Normal     187000
# 1405      1   2008        WD         Normal     275000
# 297       6   2007        WD         Normal     239000
# 1306      9   2006       New        Partial     202500
# 531       6   2008        WD         Normal     128000
# 330      11   2007        WD         Normal     119000
# 681       7   2009        WD        Abnorml     159434
# 333       7   2008        WD         Normal     207000
# 888      10   2007        WD         Normal     268000
# 1022      3   2007        WD         Normal      87000
#
# [10 rows x 81 columns]

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
df_test.sample(10)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 784   2245         180       RM         21.0     1596   Pave   NaN      Reg
# 970   2431          20       RL         60.0     7200   Pave   NaN      Reg
# 1331  2792          50  C (all)         63.0     4761   Pave   NaN      Reg
# 176   1637          60       RL         85.0    11900   Pave   NaN      Reg
# 1203  2664         120       RL         48.0     5911   Pave   NaN      Reg
# 998   2459          45       RM         51.0     6120   Pave   NaN      Reg
# 1018  2479          20       RL         62.0    14299   Pave   NaN      Reg
# 1251  2712          60       RL        105.0    11025   Pave   NaN      Reg
# 530   1991         120       RL         55.0     7301   Pave   NaN      IR1
# 758   2219          50  C (all)         52.0     5150   Pave   NaN      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 784          Lvl    AllPub  ...           0        0    NaN   GdWo
# 970          Lvl    AllPub  ...           0        0    NaN    NaN
# 1331         Lvl    AllPub  ...           0        0    NaN    NaN
# 176          Lvl    AllPub  ...         200        0    NaN    NaN
# 1203         Lvl    AllPub  ...           0        0    NaN    NaN
# 998          Lvl    AllPub  ...           0        0    NaN  MnPrv
# 1018         Lvl    AllPub  ...           0        0    NaN  MnPrv
# 1251         HLS    AllPub  ...           0        0    NaN    NaN
# 530          Lvl    AllPub  ...           0        0    NaN    NaN
# 758          Lvl    AllPub  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 784          NaN       0      7    2008        WD         Normal
# 970          NaN       0     11    2007        WD         Normal
# 1331         NaN       0     10    2006     ConLD         Normal
# 176          NaN       0      7    2009        WD         Normal
# 1203         NaN       0      3    2006        WD         Normal
# 998          NaN       0      7    2007        WD         Normal
# 1018         NaN       0      7    2007        WD         Normal
# 1251         NaN       0     10    2006        WD         Normal
# 530          NaN       0     11    2008       New        Partial
# 758          NaN       0      5    2008        WD         Normal
#
# [10 rows x 80 columns]

# %%
comb = pd.concat([df, df_test])
comb
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1454         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal   208500.0
# 1         5   2007        WD         Normal   181500.0
# 2         9   2008        WD         Normal   223500.0
# 3         2   2006        WD        Abnorml   140000.0
# 4        12   2008        WD         Normal   250000.0
# ...     ...    ...       ...            ...        ...
# 1454      6   2006        WD         Normal        NaN
# 1455      4   2006        WD        Abnorml        NaN
# 1456      9   2006        WD        Abnorml        NaN
# 1457      7   2006        WD         Normal        NaN
# 1458     11   2006        WD         Normal        NaN
#
# [2919 rows x 81 columns]

# %%
comb.SalePrice.isnull().sum()/comb.shape[0] * 100
# Out:
# 49.9828708461802

# %%
ty2 = df_test.select_dtypes("object")
ty2.transpose()
ty2.columns
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
null = []
drop = []
for i in range(0,comb.shape[1]):
    if 0 < comb.iloc[:,i].isna().sum() <= comb.shape[0]*(0.3):
        null.append(comb.columns[i]) 
    elif comb.iloc[:,i].isna().sum() > comb.shape[0]*(0.3):
        drop.append(comb.columns[i])
print(null, "\n")
print(drop)
# Out:
# ['MSZoning', 'LotFrontage', 'Utilities', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Electrical', 'BsmtFullBath', 'BsmtHalfBath', 'KitchenQual', 'Functional', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'SaleType']
#
# ['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature', 'SalePrice']

# %%
print(len(null))

# %%
ty = comb.select_dtypes("object")
for col in ty.columns.tolist():
    if col in null:
        print('{} column missing values: {}'.format(col, ty[col].isnull().sum()))
# Out:
# MSZoning column missing values: 4
# Utilities column missing values: 2
# Exterior1st column missing values: 1
# Exterior2nd column missing values: 1
# MasVnrType column missing values: 24
# BsmtQual column missing values: 81
# BsmtCond column missing values: 82
# BsmtExposure column missing values: 82
# BsmtFinType1 column missing values: 79
# BsmtFinType2 column missing values: 80
# Electrical column missing values: 1
# KitchenQual column missing values: 1
# Functional column missing values: 2
# GarageType column missing values: 157
# GarageFinish column missing values: 159
# GarageQual column missing values: 159
# GarageCond column missing values: 159
# SaleType column missing values: 1

# %%
des = []
for i in list(df):
    if i in list(null):
        if i not in list(ty):
            des.append(i)        
for col in des:          
    print('{} column missing values: {}'.format(col, df[col].isnull().sum()))
# Out:
# LotFrontage column missing values: 259
# MasVnrArea column missing values: 8
# BsmtFinSF1 column missing values: 0
# BsmtFinSF2 column missing values: 0
# BsmtUnfSF column missing values: 0
# TotalBsmtSF column missing values: 0
# BsmtFullBath column missing values: 0
# BsmtHalfBath column missing values: 0
# GarageYrBlt column missing values: 81
# GarageCars column missing values: 0
# GarageArea column missing values: 0

# %%
df.Fence.value_counts()
# Out:
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: Fence, dtype: int64

# %%
comb.describe().transpose()
# Out:
#                 count           mean           std      min       25%  \
# Id             2919.0    1460.000000    842.787043      1.0     730.5
# MSSubClass     2919.0      57.137718     42.517628     20.0      20.0
# LotFrontage    2433.0      69.305795     23.344905     21.0      59.0
# LotArea        2919.0   10168.114080   7886.996359   1300.0    7478.0
# OverallQual    2919.0       6.089072      1.409947      1.0       5.0
# OverallCond    2919.0       5.564577      1.113131      1.0       5.0
# YearBuilt      2919.0    1971.312778     30.291442   1872.0    1953.5
# YearRemodAdd   2919.0    1984.264474     20.894344   1950.0    1965.0
# MasVnrArea     2896.0     102.201312    179.334253      0.0       0.0
# BsmtFinSF1     2918.0     441.423235    455.610826      0.0       0.0
# BsmtFinSF2     2918.0      49.582248    169.205611      0.0       0.0
# BsmtUnfSF      2918.0     560.772104    439.543659      0.0     220.0
# TotalBsmtSF    2918.0    1051.777587    440.766258      0.0     793.0
# 1stFlrSF       2919.0    1159.581706    392.362079    334.0     876.0
# 2ndFlrSF       2919.0     336.483727    428.701456      0.0       0.0
# LowQualFinSF   2919.0       4.694416     46.396825      0.0       0.0
# GrLivArea      2919.0    1500.759849    506.051045    334.0    1126.0
# BsmtFullBath   2917.0       0.429894      0.524736      0.0       0.0
# BsmtHalfBath   2917.0       0.061364      0.245687      0.0       0.0
# FullBath       2919.0       1.568003      0.552969      0.0       1.0
# HalfBath       2919.0       0.380267      0.502872      0.0       0.0
# BedroomAbvGr   2919.0       2.860226      0.822693      0.0       2.0
# KitchenAbvGr   2919.0       1.044536      0.214462      0.0       1.0
# TotRmsAbvGrd   2919.0       6.451524      1.569379      2.0       5.0
# Fireplaces     2919.0       0.597122      0.646129      0.0       0.0
# GarageYrBlt    2760.0    1978.113406     25.574285   1895.0    1960.0
# GarageCars     2918.0       1.766621      0.761624      0.0       1.0
# GarageArea     2918.0     472.874572    215.394815      0.0     320.0
# WoodDeckSF     2919.0      93.709832    126.526589      0.0       0.0
# OpenPorchSF    2919.0      47.486811     67.575493      0.0       0.0
# EnclosedPorch  2919.0      23.098321     64.244246      0.0       0.0
# 3SsnPorch      2919.0       2.602261     25.188169      0.0       0.0
# ScreenPorch    2919.0      16.062350     56.184365      0.0       0.0
# PoolArea       2919.0       2.251799     35.663946      0.0       0.0
# MiscVal        2919.0      50.825968    567.402211      0.0       0.0
# MoSold         2919.0       6.213087      2.714762      1.0       4.0
# YrSold         2919.0    2007.792737      1.314964   2006.0    2007.0
# SalePrice      1460.0  180921.195890  79442.502883  34900.0  129975.0
#
#                     50%       75%       max
# Id               1460.0    2189.5    2919.0
# MSSubClass         50.0      70.0     190.0
# LotFrontage        68.0      80.0     313.0
# LotArea          9453.0   11570.0  215245.0
# OverallQual         6.0       7.0      10.0
# OverallCond         5.0       6.0       9.0
# YearBuilt        1973.0    2001.0    2010.0
# YearRemodAdd     1993.0    2004.0    2010.0
# MasVnrArea          0.0     164.0    1600.0
# BsmtFinSF1        368.5     733.0    5644.0
# BsmtFinSF2          0.0       0.0    1526.0
# BsmtUnfSF         467.0     805.5    2336.0
# TotalBsmtSF       989.5    1302.0    6110.0
# 1stFlrSF         1082.0    1387.5    5095.0
# 2ndFlrSF            0.0     704.0    2065.0
# LowQualFinSF        0.0       0.0    1064.0
# GrLivArea        1444.0    1743.5    5642.0
# BsmtFullBath        0.0       1.0       3.0
# BsmtHalfBath        0.0       0.0       2.0
# FullBath            2.0       2.0       4.0
# HalfBath            0.0       1.0       2.0
# BedroomAbvGr        3.0       3.0       8.0
# KitchenAbvGr        1.0       1.0       3.0
# TotRmsAbvGrd        6.0       7.0      15.0
# Fireplaces          1.0       1.0       4.0
# GarageYrBlt      1979.0    2002.0    2207.0
# GarageCars          2.0       2.0       5.0
# GarageArea        480.0     576.0    1488.0
# WoodDeckSF          0.0     168.0    1424.0
# OpenPorchSF        26.0      70.0     742.0
# EnclosedPorch       0.0       0.0    1012.0
# 3SsnPorch           0.0       0.0     508.0
# ScreenPorch         0.0       0.0     576.0
# PoolArea            0.0       0.0     800.0
# MiscVal             0.0       0.0   17000.0
# MoSold              6.0       8.0      12.0
# YrSold           2008.0    2009.0    2010.0
# SalePrice      163000.0  214000.0  755000.0

# %%
comb["BsmtFinSF1"] = comb["BsmtFinSF1"].fillna(0)
comb["BsmtFinSF2"] = comb["BsmtFinSF2"].fillna(0)
comb["BsmtUnfSF"] = comb["BsmtUnfSF"].fillna(0)
comb["BsmtFullBath"] = comb["BsmtFullBath"].fillna(0)
comb["BsmtHalfBath"] = comb["BsmtHalfBath"].fillna(0)

# %%
comb["LotFrontage"] = comb.LotFrontage.fillna(comb.LotFrontage.median())
comb["GarageYrBlt"] = comb["GarageYrBlt"].fillna(comb.GarageYrBlt.median())
comb["MasVnrArea"] = comb.MasVnrArea.replace(np.nan, 0)
comb.Electrical = comb.Electrical.fillna(comb.Electrical.value_counts().index[0])
comb.Functional = comb.Functional.fillna(comb.Electrical.value_counts().index[0])
comb.Exterior1st = comb.Exterior1st.fillna(comb.Exterior1st.value_counts().index[0])
comb.Exterior2nd = comb.Exterior2nd.fillna(comb.Exterior2nd.value_counts().index[0])
comb.Utilities = comb.Utilities.fillna(comb.Utilities.value_counts().index[0])
comb.MSZoning = comb.MSZoning.fillna(comb.MSZoning.value_counts().index[0])

# %%
comb["GarageCond"] = comb["GarageCond"].fillna("NA")
comb["GarageQual"] = comb["GarageQual"].fillna(comb.GarageQual.value_counts().index[0])
comb["GarageFinish"] = comb["GarageFinish"].fillna(comb.GarageFinish.value_counts().index[0])
comb["GarageType"] = comb["GarageType"].fillna(comb.GarageType.value_counts().index[0])

# %%
comb["BsmtCond"] = comb["BsmtCond"].fillna(comb.BsmtCond.value_counts().index[0])
comb["BsmtQual"] = comb["BsmtQual"].fillna(comb.BsmtQual.value_counts().index[0])
comb["BsmtExposure"] = comb["BsmtExposure"].fillna(comb.BsmtExposure.value_counts().index[0])
comb["BsmtFinType1"] = comb["BsmtFinType1"].fillna(comb.BsmtFinType1.value_counts().index[0])
comb["BsmtFinType2"] = comb["BsmtFinType2"].fillna(comb.BsmtFinType2.value_counts().index[0])

# %%
comb["GarageCars"] = comb["GarageCars"].fillna(0)
comb["KitchenQual"] = comb["KitchenQual"].fillna(comb.KitchenQual.value_counts().index[0])
comb["ExterQual"] = comb["ExterQual"].fillna(comb.ExterQual.value_counts().index[0])
comb["TotalBsmtSF"] = comb["TotalBsmtSF"].fillna(0)
comb["GarageArea"] = comb["GarageArea"].fillna(0)
comb["SaleType"] = comb["SaleType"].fillna(comb.SaleType.value_counts().index[0])
comb["MasVnrType"] = comb["MasVnrType"].fillna(comb["MasVnrType"].value_counts().index[0])

# %%
comb["Alley"] = comb["Alley"].fillna("NA")
comb["Fence"] = comb["Fence"].fillna("NA")
comb["MiscFeature"] = comb["MiscFeature"].fillna("NA")
comb["PoolQC"] = comb["PoolQC"].fillna("NA")
comb["FireplaceQu"] = comb["FireplaceQu"].fillna("NA")

# %%
comb["MasVnrType"].value_counts()

# %%
from sklearn.impute import SimpleImputer

# Fill in the lines below: imputation
my_imputer = SimpleImputer() # Your code here
comb
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1454         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  MnPrv        Shed     700
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2008        WD         Normal   208500.0
# 1         5   2007        WD         Normal   181500.0
# 2         9   2008        WD         Normal   223500.0
# 3         2   2006        WD        Abnorml   140000.0
# 4        12   2008        WD         Normal   250000.0
# ...     ...    ...       ...            ...        ...
# 1454      6   2006        WD         Normal        NaN
# 1455      4   2006        WD        Abnorml        NaN
# 1456      9   2006        WD        Abnorml        NaN
# 1457      7   2006        WD         Normal        NaN
# 1458     11   2006        WD         Normal        NaN
#
# [2919 rows x 81 columns]

# %%
null2 = []
drop2 = []
for i in range(0,comb.shape[1]):
    if 0 < comb.iloc[:,i].isna().sum() <= comb.shape[0]*(0.3):
        null2.append(comb.columns[i]) 
    elif comb.iloc[:,i].isna().sum() > comb.shape[0]*(0.3):
        drop2.append(comb.columns[i])
print(null2, "\n")
print(drop2)
let = ["Id", "MoSold", "PoolArea", "Street", "Utilities", "Functional", "LandSlope", "3SsnPorch", "Condition2", "YrSold", "BsmtFinSF2", "RoofMatl", "MiscVal", "LowQualFinSF", "LotConfig", "BsmtFinType2", "KitchenAbvGr", "RoofStyle", "Heating", "BsmtHalfBath", "BsmtFullBath", "SalePrice"]
# Out:
# []
#
# ['SalePrice']

# %%
#new_comb = pd.DataFrame(my_imputer.fit_transform(comb))
#safe = ['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']
# Out:
# 1459

# %%
comb2 = comb.drop(let, axis = 1)

# %%
print(comb2.shape)
print(comb2.isnull().sum())
# Out:
# (2919, 59)
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Alley            0
# LotShape         0
# LandContour      0
# Neighborhood     0
# Condition1       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# GrLivArea        0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenQual      0
# TotRmsAbvGrd     0
# Fireplaces       0
# FireplaceQu      0
# GarageType       0
# GarageYrBlt      0
# GarageFinish     0
# GarageCars       0
# GarageArea       0
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# ScreenPorch      0
# PoolQC           0
# Fence            0
# MiscFeature      0
# SaleType         0
# SaleCondition    0
# dtype: int64

# %%
df2 = comb2.iloc[0:1460,]
df2
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Alley LotShape LandContour  \
# 0             60       RL         65.0     8450    NA      Reg         Lvl
# 1             20       RL         80.0     9600    NA      Reg         Lvl
# 2             60       RL         68.0    11250    NA      IR1         Lvl
# 3             70       RL         60.0     9550    NA      IR1         Lvl
# 4             60       RL         84.0    14260    NA      IR1         Lvl
# ...          ...      ...          ...      ...   ...      ...         ...
# 1455          60       RL         62.0     7917    NA      Reg         Lvl
# 1456          20       RL         85.0    13175    NA      Reg         Lvl
# 1457          70       RL         66.0     9042    NA      Reg         Lvl
# 1458          20       RL         68.0     9717    NA      Reg         Lvl
# 1459          20       RL         75.0     9937    NA      Reg         Lvl
#
#      Neighborhood Condition1 BldgType  ... PavedDrive  WoodDeckSF  \
# 0         CollgCr       Norm     1Fam  ...          Y           0
# 1         Veenker      Feedr     1Fam  ...          Y         298
# 2         CollgCr       Norm     1Fam  ...          Y           0
# 3         Crawfor       Norm     1Fam  ...          Y           0
# 4         NoRidge       Norm     1Fam  ...          Y         192
# ...           ...        ...      ...  ...        ...         ...
# 1455      Gilbert       Norm     1Fam  ...          Y           0
# 1456       NWAmes       Norm     1Fam  ...          Y         349
# 1457      Crawfor       Norm     1Fam  ...          Y           0
# 1458        NAmes       Norm     1Fam  ...          Y         366
# 1459      Edwards       Norm     1Fam  ...          Y         736
#
#       OpenPorchSF  EnclosedPorch  ScreenPorch PoolQC  Fence MiscFeature  \
# 0              61              0            0     NA     NA          NA
# 1               0              0            0     NA     NA          NA
# 2              42              0            0     NA     NA          NA
# 3              35            272            0     NA     NA          NA
# 4              84              0            0     NA     NA          NA
# ...           ...            ...          ...    ...    ...         ...
# 1455           40              0            0     NA     NA          NA
# 1456            0              0            0     NA  MnPrv          NA
# 1457           60              0            0     NA  GdPrv        Shed
# 1458            0            112            0     NA     NA          NA
# 1459           68              0            0     NA     NA          NA
#
#       SaleType SaleCondition
# 0           WD        Normal
# 1           WD        Normal
# 2           WD        Normal
# 3           WD       Abnorml
# 4           WD        Normal
# ...        ...           ...
# 1455        WD        Normal
# 1456        WD        Normal
# 1457        WD        Normal
# 1458        WD        Normal
# 1459        WD        Normal
#
# [1460 rows x 59 columns]

# %%
y = df.SalePrice
X = df2.copy()

for colname in X.select_dtypes("object"):
    X[colname], _ = X[colname].factorize()

# All discrete features should now have integer dtypes (double-check this before using MI!)
discrete_features = X.dtypes == int

# %%
from sklearn.feature_selection import mutual_info_regression

importances = mutual_info_regression(X, y, discrete_features = discrete_features)
feat_importance = pd.Series(importances, index =X.columns)
mi_scores = feat_importance.sort_values(ascending=False)
plt.figure(figsize = (9, 18))
mi_scores.plot(kind = "barh", color = "teal")
plt.show()

# %%
features = mi_scores.index[0:50]
features

# %%
feat_corr = df[features].corr()
plt.figure(figsize = (20, 10))
sns.heatmap(feat_corr[feat_corr["OverallQual"] >= 0.4], vmin = 0.4, cmap = "cividis")

# %%
test_df = comb2.iloc[1460:,]
test_df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Alley LotShape LandContour  \
# 0             20       RH         80.0    11622    NA      Reg         Lvl
# 1             20       RL         81.0    14267    NA      IR1         Lvl
# 2             60       RL         74.0    13830    NA      IR1         Lvl
# 3             60       RL         78.0     9978    NA      IR1         Lvl
# 4            120       RL         43.0     5005    NA      IR1         HLS
# ...          ...      ...          ...      ...   ...      ...         ...
# 1454         160       RM         21.0     1936    NA      Reg         Lvl
# 1455         160       RM         21.0     1894    NA      Reg         Lvl
# 1456          20       RL        160.0    20000    NA      Reg         Lvl
# 1457          85       RL         62.0    10441    NA      Reg         Lvl
# 1458          60       RL         74.0     9627    NA      Reg         Lvl
#
#      Neighborhood Condition1 BldgType  ... PavedDrive  WoodDeckSF  \
# 0           NAmes      Feedr     1Fam  ...          Y         140
# 1           NAmes       Norm     1Fam  ...          Y         393
# 2         Gilbert       Norm     1Fam  ...          Y         212
# 3         Gilbert       Norm     1Fam  ...          Y         360
# 4         StoneBr       Norm   TwnhsE  ...          Y           0
# ...           ...        ...      ...  ...        ...         ...
# 1454      MeadowV       Norm    Twnhs  ...          Y           0
# 1455      MeadowV       Norm   TwnhsE  ...          Y           0
# 1456      Mitchel       Norm     1Fam  ...          Y         474
# 1457      Mitchel       Norm     1Fam  ...          Y          80
# 1458      Mitchel       Norm     1Fam  ...          Y         190
#
#       OpenPorchSF  EnclosedPorch  ScreenPorch PoolQC  Fence MiscFeature  \
# 0               0              0          120     NA  MnPrv          NA
# 1              36              0            0     NA     NA        Gar2
# 2              34              0            0     NA  MnPrv          NA
# 3              36              0            0     NA     NA          NA
# 4              82              0          144     NA     NA          NA
# ...           ...            ...          ...    ...    ...         ...
# 1454            0              0            0     NA     NA          NA
# 1455           24              0            0     NA     NA          NA
# 1456            0              0            0     NA     NA          NA
# 1457           32              0            0     NA  MnPrv        Shed
# 1458           48              0            0     NA     NA          NA
#
#       SaleType SaleCondition
# 0           WD        Normal
# 1           WD        Normal
# 2           WD        Normal
# 3           WD        Normal
# 4           WD        Normal
# ...        ...           ...
# 1454        WD        Normal
# 1455        WD       Abnorml
# 1456        WD       Abnorml
# 1457        WD        Normal
# 1458        WD        Normal
#
# [1459 rows x 59 columns]

# %%
df.GarageCars.value_counts()
df.pivot_table()

# %%
sns.boxplot(x = "GarageCars", y = "GarageArea", data = df)

# %%
sp_d = df[['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
       'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
       'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
       'SaleType', 'SaleCondition', "SalePrice"]]
sp_d

# %%
sp_d = df[['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
       'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
       'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
       'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
       'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
       'SaleType', 'SaleCondition']]

for col in sp_d.columns:
    dol_num = sp_d[col]
    dsd = sns.boxplot(x = dol_num, y = df.SalePrice,  data = df)
    dsd.set_xticklabels(dsd.get_xticklabels(), rotation=50);
    plt.show()

# %%
sns.regplot("BsmtFinSF1", "SalePrice", data = df, color = "purple")
sns.regplot("BsmtFinSF2", "SalePrice", data = df, color = "teal")

# %%
sns.countplot(df.Exterior1st)

# %% [markdown]
# ### Building test models

# %%
print(comb["GarageYrBlt"].median())
print(comb["GarageYrBlt"].mean())

# %%
comb3 = pd.get_dummies(comb2)
comb3.shape
# Out:
# (2919, 231)

# %%
X =   comb3.iloc[0:1460,]
y = df.SalePrice.values
A_test = comb3.iloc[1460:,]
print(X.shape, "\n", A_test.shape, "\n", y.shape)
# Out:
# (1460, 231)
#  (1459, 231)
#  (1460,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 100)

# %% [markdown]
# #### model 1

# %%
score = {}

# %%
L = LinearRegression()

# %%
L.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
l_predict = L.predict(X_test)

# %%
L_rmse = mean_squared_error(y_test, l_predict)
score["linear_score"] = L.score(X_test, y_test)
print("accuracy for Linear regression:", score["linear_score"])
print("rmse for Linear regression:", L_rmse)
# Out:
# accuracy for Linear regression: 0.45474443477700777
# rmse for Linear regression: 3505497195.646239

# %%
df_test["SalePrice"] = y_prediction
df_test["SalePrice"] = df_test["SalePrice"].round()
df_test

# %%
submission = df_test[["Id", "SalePrice"]]
submission.set_index("Id", inplace = True)
submission

# %%
#submission.to_csv("Submission_9.csv")

# %% [markdown]
# #### Ridge Model (2)

# %%
from sklearn.linear_model import Ridge

R = Ridge()

R.fit(X, y)

y_predict = R.predict(X_test)

# %%
df_test["SalePrice"] = y_predict
df_test["SalePrice"] = df_test["SalePrice"].round()
df_test

# %%
submission = df_test[["Id", "SalePrice"]]
submission.set_index("Id", inplace = True)
submission

# %%
#submission.to_csv("Submission_10.csv") #2nd best entry so far

# %%
combined = 'Condition1', 'Condition2'

# %% [markdown]
# #### Xgboost

# %%
from catboost import CatBoostRegressor
from xgboost import XGBRegressor

# %%
Xgb = XGBRegressor(learning_rate = 0.3, max_depth = 6)
Xgb.fit(X_train, y_train)
xgb_predict = Xgb.predict(X_test)
rmse = np.sqrt(mean_squared_error((y_test),(xgb_predict)))
#rmse_score['XGBoost'] = rmse
print("rsme for XGBRegression:", rmse)
score["Xgb"] = Xgb.score(X_test, y_test)
print("accuracy for XGBRegression:", score["Xgb"])
# Out:
# rsme for XGBRegression: 25280.140497300214
# accuracy for XGBRegression: 0.9005947207990977

# %%
my_xgb_predict = Xgb.predict(A_test)

# %%
df_test["SalePrice"] = my_xgb_predict
df_test["SalePrice"] = df_test["SalePrice"].round()
submission = df_test[["Id", "SalePrice"]]
submission.set_index("Id", inplace = True)
submission.to_csv("ames_submission/Submission_27.csv")

# %% [markdown]
# #### Catboost

# %%
Cat = CatBoostRegressor(iterations=4000, learning_rate=0.01, depth=5)
Cat.fit(X_train,y_train,verbose = 0)
cat_predict = Cat.predict(X_test)
rmse = np.sqrt(mean_squared_error((y_test),(cat_predict)))
#rmse_score['CatBoost'] = rmse
print("rmse for Catboost:",rmse)
score["Cat"] = Cat.score(X_test, y_test)
print("accuracy for Catboost:", score["Cat"])
# Out:
# rmse for Catboost: 23849.54868979981
# accuracy for Catboost: 0.911526987881204

# %%
my_caboost_predict = Cat.predict(A_test)

# %%
df_test["SalePrice"] = my_caboost_predict
df_test["SalePrice"] = df_test["SalePrice"].round()
submission = df_test[["Id", "SalePrice"]]
submission.set_index("Id", inplace = True)
submission.to_csv("ames_submission/Submission_28.csv")
